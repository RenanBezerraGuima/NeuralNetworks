# %% [markdown]
# Exemplo de utilização do Keras da aula de 3 de deep learning da universp (https://www.youtube.com/watch?v=oR2zsCuNSuc&list=PL6kmVL-xk5NetT4T00FXIVB8nwydWcbsR&index=3)

# %%
import tensorflow as tf
import keras
from keras import layers

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris = load_iris()
X = iris.data
Y = iris.target 

Y = keras.utils.to_categorical(Y, num_classes=3)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = keras.Sequential()
model.add(layers.Dense(20, input_shape=(4,), activation='tanh'))
model.add(layers.Dense(10, activation='tanh'))
model.add(layers.Dense(3, activation='softmax'))
# Out:
# /home/renanbg/tf_env/lib64/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs=200, batch_size=20, verbose=2 ,shuffle=True, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# 6/6 - 3s - 419ms/step - accuracy: 0.3750 - loss: 1.0670 - val_accuracy: 0.6000 - val_loss: 1.0525
# Epoch 2/200
# 6/6 - 0s - 15ms/step - accuracy: 0.6750 - loss: 0.9953 - val_accuracy: 0.6333 - val_loss: 0.9743
# Epoch 3/200
# 6/6 - 0s - 22ms/step - accuracy: 0.7750 - loss: 0.9470 - val_accuracy: 0.8000 - val_loss: 0.9281
# Epoch 4/200
# 6/6 - 0s - 15ms/step - accuracy: 0.6833 - loss: 0.9222 - val_accuracy: 0.7000 - val_loss: 0.8932
# Epoch 5/200
# 6/6 - 0s - 16ms/step - accuracy: 0.6583 - loss: 0.8955 - val_accuracy: 0.7000 - val_loss: 0.8634
# Epoch 6/200
# 6/6 - 0s - 15ms/step - accuracy: 0.6667 - loss: 0.8658 - val_accuracy: 0.7000 - val_loss: 0.8346
# Epoch 7/200
# 6/6 - 0s - 15ms/step - accuracy: 0.7167 - loss: 0.8348 - val_accuracy: 0.7667 - val_loss: 0.8070
# Epoch 8/200
# 6/6 - 0s - 15ms/step - accuracy: 0.8000 - loss: 0.8058 - val_accuracy: 0.8667 - val_loss: 0.7808
# Epoch 9/200
# ...
